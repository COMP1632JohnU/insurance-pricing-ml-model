# %% [markdown]
# # ***Import Library***
#
# Import the dependencies like numpy which should help in processing the arrays.
#
# Pandas also used to for making data frames, in this case the dataset to analyse are all in csv file.
#
# Matplotlib for ploting the graphs

# %%
# libraries required for project,
# Numpy is the universal standard for working with numerical data in Python.
# Pandas is mainly used for data analysis. Pandas allows importing data from various file formats such as comma-separated values, JSON, SQL,
# microsoft Excel. Pandas allows various data manipulation operations such as merging, reshaping, selecting, as well as data cleaning, and data wrangling features.
# Matplotlib is an extension of numpy used for data visualisation and graphical presentation of the dataset.
# Seaborn is a  library used toi plot simpler interface needed for machine learning, and most importantly, the plots are better looking than those in Matplotlib.
# Sklearn is probably the most useful library for machine learning in Python,the sklearn library contains efficient tools for machine learning and statistical
# modelling including classification, regression, metrics,  clustering and dimensionality reduction.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from IPython.display import display
pd.options.display.float_format = '{:,.2f}'.format
from sklearn.preprocessing import PowerTransformer
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# # ***Seaborn Reference***
#
# color palette: https://seaborn.pydata.org/tutorial/color_palettes.html#qualitative-color-palettes
#
# choose 1 of the colors by subsetting

# %%
sb.color_palette('colorblind')
# Out:
# [(0.00392156862745098, 0.45098039215686275, 0.6980392156862745),
#  (0.8705882352941177, 0.5607843137254902, 0.0196078431372549),
#  (0.00784313725490196, 0.6196078431372549, 0.45098039215686275),
#  (0.8352941176470589, 0.3686274509803922, 0.0),
#  (0.8, 0.47058823529411764, 0.7372549019607844),
#  (0.792156862745098, 0.5686274509803921, 0.3803921568627451),
#  (0.984313725490196, 0.6862745098039216, 0.8941176470588236),
#  (0.5803921568627451, 0.5803921568627451, 0.5803921568627451),
#  (0.9254901960784314, 0.8823529411764706, 0.2),
#  (0.33725490196078434, 0.7058823529411765, 0.9137254901960784)]

# %%
sb.color_palette('pastel')
# Out:
# [(0.6313725490196078, 0.788235294117647, 0.9568627450980393),
#  (1.0, 0.7058823529411765, 0.5098039215686274),
#  (0.5529411764705883, 0.8980392156862745, 0.6313725490196078),
#  (1.0, 0.6235294117647059, 0.6078431372549019),
#  (0.8156862745098039, 0.7333333333333333, 1.0),
#  (0.8705882352941177, 0.7333333333333333, 0.6078431372549019),
#  (0.9803921568627451, 0.6901960784313725, 0.8941176470588236),
#  (0.8117647058823529, 0.8117647058823529, 0.8117647058823529),
#  (1.0, 0.996078431372549, 0.6392156862745098),
#  (0.7254901960784313, 0.9490196078431372, 0.9411764705882353)]

# %%
sb.color_palette('Set3')
# Out:
# [(0.5529411764705883, 0.8274509803921568, 0.7803921568627451),
#  (1.0, 1.0, 0.7019607843137254),
#  (0.7450980392156863, 0.7294117647058823, 0.8549019607843137),
#  (0.984313725490196, 0.5019607843137255, 0.4470588235294118),
#  (0.5019607843137255, 0.6941176470588235, 0.8274509803921568),
#  (0.9921568627450981, 0.7058823529411765, 0.3843137254901961),
#  (0.7019607843137254, 0.8705882352941177, 0.4117647058823529),
#  (0.9882352941176471, 0.803921568627451, 0.8980392156862745),
#  (0.8509803921568627, 0.8509803921568627, 0.8509803921568627),
#  (0.7372549019607844, 0.5019607843137255, 0.7411764705882353),
#  (0.8, 0.9215686274509803, 0.7725490196078432),
#  (1.0, 0.9294117647058824, 0.43529411764705883)]

# %%
sb.color_palette('Spectral')
# Out:
# [(0.8853517877739331, 0.3190311418685121, 0.29042675893886966),
#  (0.9873125720876587, 0.6473663975394078, 0.3642445213379469),
#  (0.9971549404075356, 0.9118031526336025, 0.6010765090349866),
#  (0.9288735101883892, 0.9715494040753557, 0.6380622837370243),
#  (0.6334486735870821, 0.8521337946943485, 0.6436755094194541),
#  (0.2800461361014994, 0.6269896193771626, 0.7024221453287197)]

# %%
sb.color_palette('icefire')
# Out:
# [(0.33355526, 0.64107876, 0.80445484),
#  (0.28708711, 0.32912157, 0.69034504),
#  (0.15652427, 0.15348248, 0.22238175),
#  (0.22994394, 0.13076731, 0.15146314),
#  (0.61319563, 0.1824336, 0.2687872),
#  (0.91463791, 0.43668557, 0.21367954)]

# %%
sb.color_palette('tab10')
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
sb.color_palette('RdYlBu_r')
# Out:
# [(0.34648212226066905, 0.5492502883506345, 0.7527104959630911),
#  (0.6409842368319878, 0.8272971933871589, 0.90080738177624),
#  (0.9118031526336026, 0.9658592848904267, 0.9111880046136099),
#  (0.9971549404075356, 0.9118031526336025, 0.6153018069973087),
#  (0.9873125720876587, 0.647366397539408, 0.36424452133794694),
#  (0.8899653979238754, 0.28673587081891583, 0.19815455594002307)]

# %%
# #  loading the data from csv file to a pandas dataframe
# JNU_International = pd.read_csv ('/content/Dataset_1_Processed.csv')
# JNU_International = pd.read_csv ('/content/Dataset_2_Processed.csv')
# JNU_International = pd.read_csv ('/content/Dataset_3_Processed.csv')
# JNU_International = pd.read_csv ('/content/Dataset_4_Processed.csv')
# JNU_International = pd.read_csv ('/content/Dataset_5_Processed.csv')
# JNU_International = pd.read_csv ('/content/Dataset_6_Processed.csv')
# JNU_International = pd.read_csv ('/content/Dataset_7_Processed.csv')

# %% [markdown]
# #***Exploratory Data Analysis***

# %% [markdown]
# ## *Loading the dataset*

# %%
# loading the data from the csv file to a panda frame,panda uses a process called method.
# A method in object-oriented programming (OOP) is a procedure associated with a message and an object, this allows the sending
# objects to invoke behaviors and to delegate the implementation of those behaviors to the receiving object. A method in Java programming sets the behavior of a class object
jnu7 = pd.read_csv('/content/drive/MyDrive/JNU_International_Dataset/7Years_Processed_Dataset.v4.csv')

# %%
# print the dataframe
print(jnu7)
# Out:
#                           Description Description Contact  Age     Sex Claim  \
# 0                       BCME SHT CHAD           M WOOLLAM   45  Female   Yes
# 1     YAPI MERKEZI ETHIOPIAN RAILWAYS           M WOOLLAM   45  Female   Yes
# 2                    EGAT BELARUSBANK           M WOOLLAM   45  Female   Yes
# 3                 EGAT AZERBAIJAN MOF           M WOOLLAM   45  Female   Yes
# 4                BTMU SONANGOL ANGOLA           M ESDAILE   37    Male   Yes
# ...                               ...                 ...  ...     ...   ...
# 2725                 BNPP KERNEL 2019       N DE CLERMONT   55    Male   Yes
# 2726    BNPP TABCORP HOLDINGS LIMITED             D HANLY   23  Female   Yes
# 2727           DB SINGAPORE - VEDANTA       N DE CLERMONT   55    Male   Yes
# 2728                       SG SEASPAN       N DE CLERMONT   55    Male   Yes
# 2729    BNPP SKY HEDGE SEPTEMBER 2019             D HANLY   23  Female   Yes
#
# ...

# %% [markdown]
# ## *First 5 rows of the dataframe*

# %%
#  print the first 5 rows of the dataframe
jnu7.head()
# Out:
#                        Description Description Contact  Age     Sex Claim  \
# 0                    BCME SHT CHAD           M WOOLLAM   45  Female   Yes
# 1  YAPI MERKEZI ETHIOPIAN RAILWAYS           M WOOLLAM   45  Female   Yes
# 2                 EGAT BELARUSBANK           M WOOLLAM   45  Female   Yes
# 3              EGAT AZERBAIJAN MOF           M WOOLLAM   45  Female   Yes
# 4             BTMU SONANGOL ANGOLA           M ESDAILE   37    Male   Yes
#
#    Lloyds_Claim_Code Policy Reference Inception Date Expiry Date BIND/NTU  \
# 0                 55     RJDC12089A14      05-Sep-14   27-Aug-15     BIND
# 1                 55     RJDC12476A14      06-Sep-14   28-Aug-15     BIND
# 2                 55     RJDC12603A14      07-Sep-14   29-Aug-15     BIND
# 3                 55     RJDC12604A14      08-Sep-14   30-Aug-15     BIND
# 4                 55     RJDC12682A14      09-Sep-14   31-Aug-15     BIND
#
#     Territory            Obligor Trade Sector     GrossEPI    GrossWP
# ...

# %% [markdown]
# ## *Count of dataframe columns and rows*

# %%
#  number of rows and columns
jnu7.shape
# Out:
# (2730, 14)

# %% [markdown]
# ## *Loading the column headers in the  dataframe*

# %%
# print the first 10 rows with the clumn heading
# loading the column headers in the dataset.
jnu7.columns
# Out:
# Index(['Description', 'Description Contact', 'Age', 'Sex', 'Claim',
#        'Lloyds_Claim_Code', 'Policy Reference', 'Inception Date',
#        'Expiry Date', 'BIND/NTU', 'Territory', 'Obligor Trade Sector',
#        'GrossEPI', 'GrossWP'],
#       dtype='object')

# %% [markdown]
# ## *Replace the CAPS with small letters and spaces with underscore in the dataframe*

# %%
# To convert all the convert headers to small letters, as well as convert the spaces and replace them with an underscore.
jnu7.columns = jnu7.columns.str.lower().str.replace(' ', '_')
jnu7.columns
# Out:
# Index(['description', 'description_contact', 'age', 'sex', 'claim',
#        'lloyds_claim_code', 'policy_reference', 'inception_date',
#        'expiry_date', 'bind/ntu', 'territory', 'obligor_trade_sector',
#        'grossepi', 'grosswp'],
#       dtype='object')

# %% [markdown]
# ## *Checking data types in the variable*

# %%
# checking the data types in the dataframe
jnu7.dtypes
# Out:
# description              object
# description_contact      object
# age                       int64
# sex                      object
# claim                    object
# lloyds_claim_code         int64
# policy_reference         object
# inception_date           object
# expiry_date              object
# bind/ntu                 object
# territory                object
# obligor_trade_sector     object
# grossepi                float64
# grosswp                  object
# dtype: object

# %% [markdown]
# ## *Identifying the record with - values in the dataframe*

# %%
# this line of code identifies the record with the - values.
jnu7.loc[jnu7.grosswp == ' -   ', :]
# Out:
#         description description_contact  age     sex claim  lloyds_claim_code  \
# 1950  BCME SHT CHAD           M WOOLLAM   45  Female    No                 20
#
#      policy_reference inception_date expiry_date bind/ntu territory  \
# 1950     RJDC12089A14      26-Oct-18   17-Oct-19      NTU      CHAD
#
#      obligor_trade_sector     grossepi grosswp
# 1950   OIL & GAS PRODUCER 3,586,790.00    -

# %% [markdown]
# ## *Fixing the record with - values in the dataframe*

# %%
# line of code to replace the - value in grosswp
jnu7.loc[jnu7.grosswp == ' -   ', 'grosswp'] = 0

# %% [markdown]
# ## *Confirmation that the column with a status category has now been replaced in the dataframe*

# %%
# run the same code and this should replace the status of value with the category as well the grosswp with float
jnu7.astype({'sex':'category','claim':'category','lloyds_claim_code':'category','bind/ntu':'category','grosswp':'float'}).dtypes
# Out:
# description               object
# description_contact       object
# age                        int64
# sex                     category
# claim                   category
# lloyds_claim_code       category
# policy_reference          object
# inception_date            object
# expiry_date               object
# bind/ntu                category
# territory                 object
# obligor_trade_sector      object
# grossepi                 float64
# grosswp                  float64
# dtype: object

# %% [markdown]
# ## *Assigning the converted category back to the variable*

# %%
# asssign the converted data types back to the original variable
jnu7 = jnu7.astype({'sex':'category','claim':'category','lloyds_claim_code':'category','bind/ntu':'category','grosswp':'float'})

# %% [markdown]
# ## *Confirmation of dtypes in variable*

# %%
# confirmation whether data types are now converted.
jnu7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2730 entries, 0 to 2729
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   description           2730 non-null   object
#  1   description_contact   2730 non-null   object
#  2   age                   2730 non-null   int64
#  3   sex                   2730 non-null   category
#  4   claim                 2730 non-null   category
#  5   lloyds_claim_code     2730 non-null   category
#  6   policy_reference      2730 non-null   object
#  7   inception_date        2730 non-null   object
#  8   expiry_date           2730 non-null   object
#  9   bind/ntu              2730 non-null   category
#  10  territory             2730 non-null   object
#  11  obligor_trade_sector  2730 non-null   object
#  12  grossepi              2730 non-null   float64
#  13  grosswp               2730 non-null   float64
# ...

# %% [markdown]
# ## *Date format in the variable*

# %%
#  to see the date time format
jnu7.inception_date
# Out:
# 0       05-Sep-14
# 1       06-Sep-14
# 2       07-Sep-14
# 3       08-Sep-14
# 4       09-Sep-14
#           ...
# 2725    05-Nov-20
# 2726    06-Nov-20
# 2727    07-Nov-20
# 2728    08-Nov-20
# 2729    09-Nov-20
# Name: inception_date, Length: 2730, dtype: object

# %%
#  to select one record to see the date time format
jnu7.inception_date[1]
# Out:
# '06-Sep-14'

# %% [markdown]
# ## *Confirmation whether the date in the dataframe is a str or datetime*

# %%
# to confirm whether inception_date is a string or date time.
type(jnu7.inception_date[1])
# Out:
# str

# %% [markdown]
# ## *Converting the inception date and expiry date to datetime64*

# %%
# converting the inception_date & expiry_date to date time
# jnu7.astype({'inception_date':'datetime64','expiry_date':'datetime64'}).dtypes
jnu7.astype({'inception_date':'datetime64[ns]','expiry_date':'datetime64[ns]'}).dtypes
# 'datetime64[ns]'
# Out:
# description                     object
# description_contact             object
# age                              int64
# sex                           category
# claim                         category
# lloyds_claim_code             category
# policy_reference                object
# inception_date          datetime64[ns]
# expiry_date             datetime64[ns]
# bind/ntu                      category
# territory                       object
# obligor_trade_sector            object
# grossepi                       float64
# grosswp                        float64
# dtype: object

# %% [markdown]
# ## *Assigning the converted date back to the variable*

# %%
jnu7 = jnu7.astype({'inception_date':'datetime64[ns]','expiry_date':'datetime64[ns]'})

# %%
jnu7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2730 entries, 0 to 2729
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   description           2730 non-null   object
#  1   description_contact   2730 non-null   object
#  2   age                   2730 non-null   int64
#  3   sex                   2730 non-null   category
#  4   claim                 2730 non-null   category
#  5   lloyds_claim_code     2730 non-null   category
#  6   policy_reference      2730 non-null   object
#  7   inception_date        2730 non-null   datetime64[ns]
#  8   expiry_date           2730 non-null   datetime64[ns]
#  9   bind/ntu              2730 non-null   category
#  10  territory             2730 non-null   object
#  11  obligor_trade_sector  2730 non-null   object
#  12  grossepi              2730 non-null   float64
#  13  grosswp               2730 non-null   float64
# ...

# %% [markdown]
# ## *Checking the datetime stamp in index 0*

# %%
# to check the datetime time stamp
jnu7.inception_date[1]
# Out:
# Timestamp('2014-09-06 00:00:00')

# %%
# to convert the inception_date & expiry_date back to object, but this time, the object would be date object not the string object.
jnu7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2730 entries, 0 to 2729
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   description           2730 non-null   object
#  1   description_contact   2730 non-null   object
#  2   age                   2730 non-null   int64
#  3   sex                   2730 non-null   category
#  4   claim                 2730 non-null   category
#  5   lloyds_claim_code     2730 non-null   category
#  6   policy_reference      2730 non-null   object
#  7   inception_date        2730 non-null   datetime64[ns]
#  8   expiry_date           2730 non-null   datetime64[ns]
#  9   bind/ntu              2730 non-null   category
#  10  territory             2730 non-null   object
#  11  obligor_trade_sector  2730 non-null   object
#  12  grossepi              2730 non-null   float64
#  13  grosswp               2730 non-null   float64
# ...

# %%
# to show the beggining of the inception and the maximum of the inception to be able to filter
jnu7.inception_date.min(), jnu7.inception_date.max()
# Out:
# (Timestamp('2014-09-05 00:00:00'), Timestamp('2020-11-09 00:00:00'))

# %%
# to compute each year how many policies renewed using the resample rule is a short cut for excel pure table.  Rule here is to convert
# the inception_date to year as an index in python.
jnu7.resample('Y',on='inception_date').count()
# Out:
# /tmp/ipython-input-3774571822.py:3: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   jnu7.resample('Y',on='inception_date').count()
#                 description  description_contact  age  sex  claim  \
# inception_date
# 2014-12-31              118                  118  118  118    118
# 2015-12-31              399                  399  399  399    399
# 2016-12-31              263                  263  263  263    263
# 2017-12-31              294                  294  294  294    294
# 2018-12-31              887                  887  887  887    887
# 2019-12-31              455                  455  455  455    455
# 2020-12-31              314                  314  314  314    314
#
#                 lloyds_claim_code  policy_reference  expiry_date  bind/ntu  \
# inception_date
# 2014-12-31                    118               118          118       118
# ...

# %%
# to compute each year how many policies renewed using the resample rule, rule meaning whether the intention is perform, the action yearly,
# monthly, in this case, the intention is to perform the action yearly.
jnu7.resample('Y',on='inception_date')['sex'].count()
# Out:
# /tmp/ipython-input-2595125216.py:3: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   jnu7.resample('Y',on='inception_date')['sex'].count()
# inception_date
# 2014-12-31    118
# 2015-12-31    399
# 2016-12-31    263
# 2017-12-31    294
# 2018-12-31    887
# 2019-12-31    455
# 2020-12-31    314
# Freq: YE-DEC, Name: sex, dtype: int64

# %%
jnu7.inception_date.min(), jnu7.inception_date.max()
# Out:
# (Timestamp('2014-09-05 00:00:00'), Timestamp('2020-11-09 00:00:00'))

# %% [markdown]
# ## *Policy reference count year on year*

# %%
jnu7.resample('Y',on='inception_date').count()
# Out:
# /tmp/ipython-input-74870776.py:1: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   jnu7.resample('Y',on='inception_date').count()
#                 description  description_contact  age  sex  claim  \
# inception_date
# 2014-12-31              118                  118  118  118    118
# 2015-12-31              399                  399  399  399    399
# 2016-12-31              263                  263  263  263    263
# 2017-12-31              294                  294  294  294    294
# 2018-12-31              887                  887  887  887    887
# 2019-12-31              455                  455  455  455    455
# 2020-12-31              314                  314  314  314    314
#
#                 lloyds_claim_code  policy_reference  expiry_date  bind/ntu  \
# inception_date
# 2014-12-31                    118               118          118       118
# ...

# %%
jnu7.resample('Y',on='inception_date')['policy_reference'].count()
# Out:
# /tmp/ipython-input-1297909087.py:1: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   jnu7.resample('Y',on='inception_date')['policy_reference'].count()
# inception_date
# 2014-12-31    118
# 2015-12-31    399
# 2016-12-31    263
# 2017-12-31    294
# 2018-12-31    887
# 2019-12-31    455
# 2020-12-31    314
# Freq: YE-DEC, Name: policy_reference, dtype: int64

# %% [markdown]
# ## *Categorical Features*
#
# Implying a yes or No
#
#
# ##Age
# ##Sex
# ##Claim
# ##BIND/NTU
# ##Lloyds_Claim_Code
#
# ##Other
# ##Description
# ##Description Contact
# ##Inception Date
# ##Expriry Date
# ##Policy reference
# ##Territory
# ##Obligor Trade Territory
#
#
# #Target Variable:
#
# ####Gross Estimated Premium Income
# ####Gross Written Premium

# %% [markdown]
# ## *Ways Checking for missing Values*
#
# There are missing values, handling missing values in Description Contact, Age and Claim. In this using imputation to replace the missing values, in cases where the dataset is large like 40,000 records, perhaps, dropping the missing values could be ideal here because we are working with 2730 records, the ideal method would be using imputation which is a statictical values like mean, median, mode to replace the missing values

# %% [markdown]
# ## *Central Tendencies*
#
# 1. Mean = average of all the values
# 2. Median = middle values in the array
# 3. Mode = numbers repeated more

# %% [markdown]
# ## *Further Data Analysis*

# %%
# from IPython.display import display
# pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# ## *Statistical measures of the datset*

# %%
# statistical measures of the datset
jnu7.describe()
# Out:
#            age                 inception_date                    expiry_date  \
# count 2,730.00                           2730                           2730
# mean     38.08  2017-12-28 22:17:08.571428864  2018-10-17 05:08:34.285714176
# min      23.00            2014-09-05 00:00:00            2015-08-27 00:00:00
# 25%      31.00            2016-06-14 06:00:00            2017-06-05 06:00:00
# 50%      37.00            2018-04-18 00:00:00            2018-11-11 12:00:00
# 75%      45.00            2019-02-12 18:00:00            2020-01-21 18:00:00
# max      55.00            2020-11-09 00:00:00            2021-10-30 00:00:00
# std      10.15                            NaN                            NaN
#
#           grossepi      grosswp
# count     2,730.00     2,730.00
# mean    654,170.46   608,466.98
# min           5.00         0.00
# 25%     116,343.25    87,323.25
# 50%     385,445.00   332,818.00
# 75%     851,343.00   805,803.00
# max   6,634,692.00 6,634,692.00
# ...

# %%
# statistical measures of the datset
jnu7.describe().T
# Out:
#                   count                           mean                  min  \
# age            2,730.00                          38.08                23.00
# inception_date     2730  2017-12-28 22:17:08.571428864  2014-09-05 00:00:00
# expiry_date        2730  2018-10-17 05:08:34.285714176  2015-08-27 00:00:00
# grossepi       2,730.00                     654,170.46                 5.00
# grosswp        2,730.00                     608,466.98                 0.00
#
#                                 25%                  50%                  75%  \
# age                           31.00                37.00                45.00
# inception_date  2016-06-14 06:00:00  2018-04-18 00:00:00  2019-02-12 18:00:00
# expiry_date     2017-06-05 06:00:00  2018-11-11 12:00:00  2020-01-21 18:00:00
# grossepi                 116,343.25           385,445.00           851,343.00
# grosswp                   87,323.25           332,818.00           805,803.00
#
# ...

# %% [markdown]
# # ***Various Seaborn Plots showing the mix of the dataset***

# %%
# the next step is finding the distribution of the age value
sb.set()
plt.figure(figsize=(10,10))
# code 5 tells how the values are distributed in the dataset
sb.distplot(jnu7['age'])
plt.title('Age Distribution In JNU International')
plt.show()
# Out:
# /tmp/ipython-input-2930074629.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(jnu7['age'])

# %%
plt.figure(figsize=(10,10))
sb.barplot(x='description_contact', y='age',data=jnu7)
plt.title('Description Contact Ages in JNU International')
plt.show()

# %%
# Gender Column
plt.figure(figsize=(10,10))
sb.countplot(x='sex',data=jnu7)
plt.title('Sex Destribution in JNU International')
plt.show()

# %%
jnu7['sex'].value_counts()
# Out:
# sex
# Male      1701
# Female    1029
# Name: count, dtype: int64

# %%
# # Lloyds claim code distribution plot
# sb.set()
# plt.figure(figsize=(10,10))
# # code 5 tells how the values are distributed in the dataset
# sb.kdeplot(JNU['Lloyds_Claim_Code'])
# plt.title('Lloyds_Claim_Code Distribution In JNU International')
# plt.show()

# %%
sb.set()
plt.figure(figsize=(10,10))
# code 5 tells how the values are distributed in the dataset
sb.kdeplot(jnu7['grossepi'])
sb.rugplot(jnu7['lloyds_claim_code'])
plt.title('Lloyds_Claim_Code Distribution In JNU International')
plt.show()

# %%
jnu7['lloyds_claim_code'].value_counts()
# Out:
# lloyds_claim_code
# 55    1917
# 20     813
# Name: count, dtype: int64

# %%
# Claim Column
plt.figure(figsize=(10,10))
sb.countplot(x='claim',data=jnu7)
plt.title('Claim Destribution in JNU International')
plt.show()

# %%
jnu7['claim'].value_counts()
# Out:
# claim
# Yes    1917
# No      813
# Name: count, dtype: int64

# %%
# BIND/NTU Column
plt.figure(figsize=(10,10))
sb.countplot(x='bind/ntu',data=jnu7)
plt.title('BIND/NTU Destribution in JNU International')
# plt.fill_between('BIND/NTU', 195, where=('BIND/NTU' > 195), facecolor='g', alpha=0.6)
plt.show()

# %%
jnu7['bind/ntu'].value_counts()
# Out:
# bind/ntu
# BIND    2554
# NTU      176
# Name: count, dtype: int64

# %%
# Distribution of GrossEPI
plt.figure(figsize=(10,10))
# code 5 tells how the values are distributed in the dataset
sb.distplot(jnu7['grossepi'])
plt.title('GrossEPI Distribution In JNU International')
plt.show()
# Out:
# /tmp/ipython-input-3966103019.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(jnu7['grossepi'])

# %% [markdown]
# # ***Further Data Pre-Processing***

# %%
# axis 0 referes to the row, 1 = column
jnu7.drop(['description',
        'policy_reference', 'inception_date',
       'expiry_date',  'territory', 'obligor_trade_sector',
       ], axis=1, inplace=True)
jnu7.head()
# Out:
#   description_contact  age     sex claim lloyds_claim_code bind/ntu  \
# 0           M WOOLLAM   45  Female   Yes                55     BIND
# 1           M WOOLLAM   45  Female   Yes                55     BIND
# 2           M WOOLLAM   45  Female   Yes                55     BIND
# 3           M WOOLLAM   45  Female   Yes                55     BIND
# 4           M ESDAILE   37    Male   Yes                55     BIND
#
#       grossepi      grosswp
# 0 1,793,395.00 1,793,395.00
# 1   263,714.00   263,714.00
# 2   387,181.19   387,181.19
# 3   161,985.00   161,985.00
# 4   546,305.00   546,305.00

# %% [markdown]
# # *Encoding the categorical features*

# %%
# using one hot encoding fucntion get dummy to convert description contact into numeric data of its own.
pd.concat([jnu7, pd.get_dummies(jnu7.description_contact)], axis=1)
# Out:
#      description_contact  age     sex claim lloyds_claim_code bind/ntu  \
# 0              M WOOLLAM   45  Female   Yes                55     BIND
# 1              M WOOLLAM   45  Female   Yes                55     BIND
# 2              M WOOLLAM   45  Female   Yes                55     BIND
# 3              M WOOLLAM   45  Female   Yes                55     BIND
# 4              M ESDAILE   37    Male   Yes                55     BIND
# ...                  ...  ...     ...   ...               ...      ...
# 2725       N DE CLERMONT   55    Male   Yes                55     BIND
# 2726             D HANLY   23  Female   Yes                55     BIND
# 2727       N DE CLERMONT   55    Male   Yes                55     BIND
# 2728       N DE CLERMONT   55    Male   Yes                55     BIND
# 2729             D HANLY   23  Female   Yes                55     BIND
#
#          grossepi      grosswp  A COLCLOUGH  D HANLY  M ESDAILE  M WOOLLAM  \
# ...

# %%
jnu7 = pd.concat([jnu7, pd.get_dummies(jnu7.description_contact)], axis=1)
jnu7.head()
# Out:
#   description_contact  age     sex claim lloyds_claim_code bind/ntu  \
# 0           M WOOLLAM   45  Female   Yes                55     BIND
# 1           M WOOLLAM   45  Female   Yes                55     BIND
# 2           M WOOLLAM   45  Female   Yes                55     BIND
# 3           M WOOLLAM   45  Female   Yes                55     BIND
# 4           M ESDAILE   37    Male   Yes                55     BIND
#
#       grossepi      grosswp  A COLCLOUGH  D HANLY  M ESDAILE  M WOOLLAM  \
# 0 1,793,395.00 1,793,395.00        False    False      False       True
# 1   263,714.00   263,714.00        False    False      False       True
# 2   387,181.19   387,181.19        False    False      False       True
# 3   161,985.00   161,985.00        False    False      False       True
# 4   546,305.00   546,305.00        False    False       True      False
#
#    N DE CLERMONT  S JAMES
# 0          False    False
# 1          False    False
# 2          False    False
# ...

# %%
# encoding sex
jnu7['female']=pd.get_dummies(jnu7.sex)['Female']
jnu7['male']=pd.get_dummies(jnu7.sex)['Male']
jnu7.head()
# Out:
#   description_contact  age     sex claim lloyds_claim_code bind/ntu  \
# 0           M WOOLLAM   45  Female   Yes                55     BIND
# 1           M WOOLLAM   45  Female   Yes                55     BIND
# 2           M WOOLLAM   45  Female   Yes                55     BIND
# 3           M WOOLLAM   45  Female   Yes                55     BIND
# 4           M ESDAILE   37    Male   Yes                55     BIND
#
#       grossepi      grosswp  A COLCLOUGH  D HANLY  M ESDAILE  M WOOLLAM  \
# 0 1,793,395.00 1,793,395.00        False    False      False       True
# 1   263,714.00   263,714.00        False    False      False       True
# 2   387,181.19   387,181.19        False    False      False       True
# 3   161,985.00   161,985.00        False    False      False       True
# 4   546,305.00   546,305.00        False    False       True      False
#
#    N DE CLERMONT  S JAMES  female   male
# 0          False    False    True  False
# ...

# %%
# dropping the column sex
jnu7.drop(['sex',], axis=1, inplace=True)
jnu7.head()
# Out:
#   description_contact  age claim lloyds_claim_code bind/ntu     grossepi  \
# 0           M WOOLLAM   45   Yes                55     BIND 1,793,395.00
# 1           M WOOLLAM   45   Yes                55     BIND   263,714.00
# 2           M WOOLLAM   45   Yes                55     BIND   387,181.19
# 3           M WOOLLAM   45   Yes                55     BIND   161,985.00
# 4           M ESDAILE   37   Yes                55     BIND   546,305.00
#
#        grosswp  A COLCLOUGH  D HANLY  M ESDAILE  M WOOLLAM  N DE CLERMONT  \
# 0 1,793,395.00        False    False      False       True          False
# 1   263,714.00        False    False      False       True          False
# 2   387,181.19        False    False      False       True          False
# 3   161,985.00        False    False      False       True          False
# 4   546,305.00        False    False       True      False          False
#
#    S JAMES  female   male
# 0    False    True  False
# 1    False    True  False
# ...

# %%
# changing the caps from capital letters to small letters
jnu7['claim'] = jnu7.claim.str.lower()
jnu7['bind/ntu'] = jnu7['bind/ntu'].str.lower()

jnu7.head()
# Out:
#   description_contact  age claim lloyds_claim_code bind/ntu     grossepi  \
# 0           M WOOLLAM   45   yes                55     bind 1,793,395.00
# 1           M WOOLLAM   45   yes                55     bind   263,714.00
# 2           M WOOLLAM   45   yes                55     bind   387,181.19
# 3           M WOOLLAM   45   yes                55     bind   161,985.00
# 4           M ESDAILE   37   yes                55     bind   546,305.00
#
#        grosswp  A COLCLOUGH  D HANLY  M ESDAILE  M WOOLLAM  N DE CLERMONT  \
# 0 1,793,395.00        False    False      False       True          False
# 1   263,714.00        False    False      False       True          False
# 2   387,181.19        False    False      False       True          False
# 3   161,985.00        False    False      False       True          False
# 4   546,305.00        False    False       True      False          False
#
#    S JAMES  female   male
# 0    False    True  False
# 1    False    True  False
# ...

# %%
jnu7.drop(['description_contact',], axis=1, inplace=True)
jnu7.head()
# Out:
#    age claim lloyds_claim_code bind/ntu     grossepi      grosswp  \
# 0   45   yes                55     bind 1,793,395.00 1,793,395.00
# 1   45   yes                55     bind   263,714.00   263,714.00
# 2   45   yes                55     bind   387,181.19   387,181.19
# 3   45   yes                55     bind   161,985.00   161,985.00
# 4   37   yes                55     bind   546,305.00   546,305.00
#
#    A COLCLOUGH  D HANLY  M ESDAILE  M WOOLLAM  N DE CLERMONT  S JAMES  female  \
# 0        False    False      False       True          False    False    True
# 1        False    False      False       True          False    False    True
# 2        False    False      False       True          False    False    True
# 3        False    False      False       True          False    False    True
# 4        False    False       True      False          False    False   False
#
#     male
# 0  False
# 1  False
# 2  False
# 3  False
# 4   True

# %%
# encoding the column claim & bind/ntu, as well as dropping the claim and bind/ntu after encoding using the panda series get dummies.
pd.concat([jnu7, pd.get_dummies(jnu7.claim), pd.get_dummies(jnu7['bind/ntu'])], axis=1).drop(['claim', 'bind/ntu'], axis=1)
# j5yrs.head()
# Out:
#       age lloyds_claim_code     grossepi      grosswp  A COLCLOUGH  D HANLY  \
# 0      45                55 1,793,395.00 1,793,395.00        False    False
# 1      45                55   263,714.00   263,714.00        False    False
# 2      45                55   387,181.19   387,181.19        False    False
# 3      45                55   161,985.00   161,985.00        False    False
# 4      37                55   546,305.00   546,305.00        False    False
# ...   ...               ...          ...          ...          ...      ...
# 2725   55                55   470,902.00   470,902.00        False    False
# 2726   23                55   371,112.00   371,112.00        False     True
# 2727   55                55   228,536.00   228,536.00        False    False
# 2728   55                55   543,015.00   543,015.00        False    False
# 2729   23                55    74,912.00    74,912.00        False     True
#
# ...

# %%
# assigning the encoded columns back to the dataframe
jnu7 = pd.concat([jnu7, pd.get_dummies(jnu7.claim), pd.get_dummies(jnu7['bind/ntu'])], axis=1).drop(['claim', 'bind/ntu'], axis=1)

# %%
jnu7
# Out:
#       age lloyds_claim_code     grossepi      grosswp  A COLCLOUGH  D HANLY  \
# 0      45                55 1,793,395.00 1,793,395.00        False    False
# 1      45                55   263,714.00   263,714.00        False    False
# 2      45                55   387,181.19   387,181.19        False    False
# 3      45                55   161,985.00   161,985.00        False    False
# 4      37                55   546,305.00   546,305.00        False    False
# ...   ...               ...          ...          ...          ...      ...
# 2725   55                55   470,902.00   470,902.00        False    False
# 2726   23                55   371,112.00   371,112.00        False     True
# 2727   55                55   228,536.00   228,536.00        False    False
# 2728   55                55   543,015.00   543,015.00        False    False
# 2729   23                55    74,912.00    74,912.00        False     True
#
# ...

# %%
# replace the space in the encoded decription contact with an underscore and replace the capital letters with small letters.
jnu7.columns = jnu7.columns.str.lower().str.replace(' ', '_')
jnu7.head()
# Out:
#    age lloyds_claim_code     grossepi      grosswp  a_colclough  d_hanly  \
# 0   45                55 1,793,395.00 1,793,395.00        False    False
# 1   45                55   263,714.00   263,714.00        False    False
# 2   45                55   387,181.19   387,181.19        False    False
# 3   45                55   161,985.00   161,985.00        False    False
# 4   37                55   546,305.00   546,305.00        False    False
#
#    m_esdaile  m_woollam  n_de_clermont  s_james  female   male     no   yes  \
# 0      False       True          False    False    True  False  False  True
# 1      False       True          False    False    True  False  False  True
# 2      False       True          False    False    True  False  False  True
# 3      False       True          False    False    True  False  False  True
# 4       True      False          False    False   False   True  False  True
#
#    bind    ntu
# 0  True  False
# 1  True  False
# 2  True  False
# ...

# %%
jnu7.head()
# Out:
#    age lloyds_claim_code     grossepi      grosswp  a_colclough  d_hanly  \
# 0   45                55 1,793,395.00 1,793,395.00        False    False
# 1   45                55   263,714.00   263,714.00        False    False
# 2   45                55   387,181.19   387,181.19        False    False
# 3   45                55   161,985.00   161,985.00        False    False
# 4   37                55   546,305.00   546,305.00        False    False
#
#    m_esdaile  m_woollam  n_de_clermont  s_james  female   male     no   yes  \
# 0      False       True          False    False    True  False  False  True
# 1      False       True          False    False    True  False  False  True
# 2      False       True          False    False    True  False  False  True
# 3      False       True          False    False    True  False  False  True
# 4       True      False          False    False   False   True  False  True
#
#    bind    ntu
# 0  True  False
# 1  True  False
# 2  True  False
# ...

# %% [markdown]
# # ***Splitting the Features and Target Variables***
#
# The next step is splitting the Features and Target Variables, which would be the Gross Estmated Written premium, if the instruction to python is to remove a column, mention the axis as 1, and the instruction to python is remove a row, mention the axis as 0.

# %%
# to select multiple columns in a dataframe, the list function is best practice where the syntax expected is double square brackets. panda datframe 2 brackets and panda series 1 bracket.
# https://pandas.pydata.org/pandas-docs/stable/getting_started/intro_tutorials/03_subset_data.html
x = jnu7[['age', 'lloyds_claim_code', 'grosswp', 'a_colclough','d_hanly', 'm_esdaile', 'm_woollam', 'n_de_clermont', 's_james', 'female','male','no','yes','bind', 'ntu']]
y = jnu7[['grossepi']]

# %%
# independent variable
x
# Out:
#       age lloyds_claim_code      grosswp  a_colclough  d_hanly  m_esdaile  \
# 0      45                55 1,793,395.00        False    False      False
# 1      45                55   263,714.00        False    False      False
# 2      45                55   387,181.19        False    False      False
# 3      45                55   161,985.00        False    False      False
# 4      37                55   546,305.00        False    False       True
# ...   ...               ...          ...          ...      ...        ...
# 2725   55                55   470,902.00        False    False      False
# 2726   23                55   371,112.00        False     True      False
# 2727   55                55   228,536.00        False    False      False
# 2728   55                55   543,015.00        False    False      False
# 2729   23                55    74,912.00        False     True      False
#
#       m_woollam  n_de_clermont  s_james  female   male     no   yes  bind  \
# ...

# %%
# dependent varaible.
y
# Out:
#          grossepi
# 0    1,793,395.00
# 1      263,714.00
# 2      387,181.19
# 3      161,985.00
# 4      546,305.00
# ...           ...
# 2725   470,902.00
# 2726   371,112.00
# 2727   228,536.00
# 2728   543,015.00
# 2729    74,912.00
#
# [2730 rows x 1 columns]

# %% [markdown]
# # ***Splitting the data into Training Data and Testing Data***

# %%
# splitting the xtrain, xtrain and y tain and ytest on a 80:205 ratio, 80% training and 20% testing
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=2)

# %%
print(x.shape, x_train.shape, x_test.shape)
# Out:
# (2730, 15) (2184, 15) (546, 15)

# %% [markdown]
# # ***Showing the number of claims made in the variable***

# %%
# number of yes claims, as this is the a major independent variable
x['yes'].sum()
# Out:
# np.int64(1917)

# %%
# number of no claims, as this is the a major independent variable
x['no'].sum()
# Out:
# np.int64(813)

# %%
# sum of male
x['male'].sum()
# Out:
# np.int64(1701)

# %%
# sum of female in the dataframe
x['female'].sum()
# Out:
# np.int64(1029)

# %%
# find out the number of people who claimed and if they are female.
x.loc[(x.yes == 1) & (x.female == 1)]
# Out:
#       age lloyds_claim_code      grosswp  a_colclough  d_hanly  m_esdaile  \
# 0      45                55 1,793,395.00        False    False      False
# 1      45                55   263,714.00        False    False      False
# 2      45                55   387,181.19        False    False      False
# 3      45                55   161,985.00        False    False      False
# 5      45                55    75,000.00        False    False      False
# ...   ...               ...          ...          ...      ...        ...
# 2717   23                55   356,602.00        False     True      False
# 2722   45                55 3,333,438.00        False    False      False
# 2723   40                55   294,367.00         True    False      False
# 2726   23                55   371,112.00        False     True      False
# 2729   23                55    74,912.00        False     True      False
#
#       m_woollam  n_de_clermont  s_james  female   male     no   yes  bind  \
# ...

# %%
# find out the number of people who claimed and if they are male.
x.loc[(x.yes == 1) & (x.male == 1)]
# Out:
#       age lloyds_claim_code    grosswp  a_colclough  d_hanly  m_esdaile  \
# 4      37                55 546,305.00        False    False       True
# 7      37                55 165,476.25        False    False       True
# 8      37                55 868,332.00        False    False       True
# 9      37                55 578,260.92        False    False       True
# 10     37                55 624,705.00        False    False       True
# ...   ...               ...        ...          ...      ...        ...
# 2721   55                55  89,260.00        False    False      False
# 2724   55                55 578,958.00        False    False      False
# 2725   55                55 470,902.00        False    False      False
# 2727   55                55 228,536.00        False    False      False
# 2728   55                55 543,015.00        False    False      False
#
#       m_woollam  n_de_clermont  s_james  female  male     no   yes  bind  \
# ...

# %%
# find out the number of 'yes' claims, lloyds claim code assigned with value 55, if they are female.
x.loc[(x.yes == 1) & (x.female == 1) & (x.lloyds_claim_code == 55)]
# Out:
#       age lloyds_claim_code      grosswp  a_colclough  d_hanly  m_esdaile  \
# 0      45                55 1,793,395.00        False    False      False
# 1      45                55   263,714.00        False    False      False
# 2      45                55   387,181.19        False    False      False
# 3      45                55   161,985.00        False    False      False
# 5      45                55    75,000.00        False    False      False
# ...   ...               ...          ...          ...      ...        ...
# 2717   23                55   356,602.00        False     True      False
# 2722   45                55 3,333,438.00        False    False      False
# 2723   40                55   294,367.00         True    False      False
# 2726   23                55   371,112.00        False     True      False
# 2729   23                55    74,912.00        False     True      False
#
#       m_woollam  n_de_clermont  s_james  female   male     no   yes  bind  \
# ...

# %%
# find out the number of 'yes' claims, lloyds claim code assigned with value 55, if they are male.
x.loc[(x.yes == 1) & (x.male == 1) & (x.lloyds_claim_code == 55)]
# Out:
#       age lloyds_claim_code    grosswp  a_colclough  d_hanly  m_esdaile  \
# 4      37                55 546,305.00        False    False       True
# 7      37                55 165,476.25        False    False       True
# 8      37                55 868,332.00        False    False       True
# 9      37                55 578,260.92        False    False       True
# 10     37                55 624,705.00        False    False       True
# ...   ...               ...        ...          ...      ...        ...
# 2721   55                55  89,260.00        False    False      False
# 2724   55                55 578,958.00        False    False      False
# 2725   55                55 470,902.00        False    False      False
# 2727   55                55 228,536.00        False    False      False
# 2728   55                55 543,015.00        False    False      False
#
#       m_woollam  n_de_clermont  s_james  female  male     no   yes  bind  \
# ...

# %%
# find out the number of 'no' claims, lloyds claim code assigned with value 20, if they are male.
x.loc[(x.no == 1) & (x.male == 1) & (x.lloyds_claim_code == 20)]
# Out:
#       age lloyds_claim_code  grosswp  a_colclough  d_hanly  m_esdaile  \
# 98     37                20     0.00        False    False       True
# 99     37                20     0.00        False    False       True
# 100    37                20     0.00        False    False       True
# 101    37                20     0.00        False    False       True
# 102    37                20     0.00        False    False       True
# ...   ...               ...      ...          ...      ...        ...
# 2289   37                20     0.00        False    False       True
# 2321   31                20     0.00        False    False      False
# 2323   55                20     0.00        False    False      False
# 2326   31                20     0.00        False    False      False
# 2328   55                20     0.00        False    False      False
#
#       m_woollam  n_de_clermont  s_james  female  male    no    yes   bind  \
# ...

# %%
# find out the number of 'no' claims, lloyds claim code assigned with value 20, if they are female.
x.loc[(x.no == 1) & (x.female == 1) & (x.lloyds_claim_code == 20)]
# Out:
#       age lloyds_claim_code    grosswp  a_colclough  d_hanly  m_esdaile  \
# 6      45                20       0.00        False    False      False
# 111    45                20 896,909.61        False    False      False
# 117    45                20 948,060.00        False    False      False
# 118    45                20 368,505.34        False    False      False
# 119    45                20 264,993.53        False    False      False
# ...   ...               ...        ...          ...      ...        ...
# 2291   45                20       0.00        False    False      False
# 2322   23                20       0.00        False     True      False
# 2324   45                20       0.00        False    False      False
# 2325   23                20       0.00        False     True      False
# 2327   23                20       0.00        False     True      False
#
#       m_woollam  n_de_clermont  s_james  female   male    no    yes   bind  \
# ...

# %% [markdown]
# # ***Model Trianing Approach = Linear Regression***

# %%
# Prediction on training data, calling up and instance of linear regression and assigning it to app.
# https://www.analyticsvidhya.com/blog/2021/05/multiple-linear-regression-using-python-and-scikit-learn/#h2_3
app = LinearRegression()

# %%
# fitting the data into x_train, y_train
app.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# This line of code would plot the line in the datapoints

# %%
# finally, to execute this then, the model will be ready, now the  x_test data and use this data for the prediction of forcast.
forcast = app.predict(x_test)
forcast
# Out:
# array([[ 7.86861091e+05],
#        [ 5.04663485e+04],
#        [ 3.90243308e+05],
#        [ 6.45064796e+05],
#        [ 1.04943434e+06],
#        [ 5.78688318e+05],
#        [ 1.01488879e+06],
#        [ 6.86953655e+04],
#        [ 3.68730278e+06],
#        [ 2.27148108e+04],
#        [ 8.12828579e+05],
#        [ 3.13878114e+05],
#        [ 1.10986802e+05],
#        [ 1.45964875e+05],
#        [ 6.00359531e+05],
#        [ 5.22060097e+05],
#        [ 7.19228402e+05],
#        [ 1.01734948e+06],
#        [ 4.70119048e+05],
#        [ 1.16085668e+06],
#        [ 7.73031207e+03],
#        [ 2.60854901e+04],
#        [ 7.92339256e+04],
#        [ 1.99842976e+05],
#        [ 2.76536789e+04],
#        [ 8.64241218e+02],
#        [ 8.23243639e+05],
#        [ 4.32871319e+05],
#        [ 6.54932386e+04],
#        [ 7.79244550e+05],
#        [ 1.93990709e+04],
#        [ 6.40389698e+05],
#        [ 1.51071806e+05],
#        [ 3.95030663e+06],
#        [ 5.35007121e+05],
# ...

# %% [markdown]
# # ***Model Evaluation metrics output & Accuracy***

# %%
# predicting the accuracy score
# https://www.analyticsvidhya.com/blog/2021/05/multiple-linear-regression-using-python-and-scikit-learn/#h2_6
score=r2_score(y_test,forcast)
print('r2 score is ',score)
print('mean_sqrd_error is==',mean_squared_error(y_test,forcast))
print('root_mean_squared error is==',np.sqrt(mean_squared_error(y_test,forcast)))
print('mean_absolute_error is==',mean_absolute_error(y_test,forcast))
# Out:
# r2 score is  0.9484764797059273
# mean_sqrd_error is== 32141659417.368008
# root_mean_squared error is== 179280.95107224304
# mean_absolute_error is== 56367.29865806084

# %% [markdown]
# # ***Built a Predictive Model to feed the Algorithm***

# %%
# to reset index in chronological order.
x_test.reset_index(drop=True)
# Out:
#      age lloyds_claim_code      grosswp  a_colclough  d_hanly  m_esdaile  \
# 0     45                55   776,088.00        False    False      False
# 1     55                20    58,458.00        False    False      False
# 2     55                55   406,616.00        False    False      False
# 3     37                20   618,822.00        False    False       True
# 4     31                55 1,071,432.00        False    False      False
# ..   ...               ...          ...          ...      ...        ...
# 541   55                20   579,382.00        False    False      False
# 542   37                20   162,458.00        False    False       True
# 543   55                55   268,332.00        False    False      False
# 544   31                55   142,805.00        False    False      False
# 545   37                55   319,729.00        False    False       True
#
#      m_woollam  n_de_clermont  s_james  female   male     no    yes  bind  \
# ...

# %% [markdown]
# # ***Creating a function for the predictive model***

# %%
# creating a function forecast
def forecast(x):
  result = app.predict(x)
  result = result[0]
  return result

# %%
# adding one column to the dataframe.
x_test['forecast'] = forcast
x_test.head()
# Out:
#       age lloyds_claim_code      grosswp  a_colclough  d_hanly  m_esdaile  \
# 833    45                55   776,088.00        False    False      False
# 1826   55                20    58,458.00        False    False      False
# 2247   55                55   406,616.00        False    False      False
# 1972   37                20   618,822.00        False    False       True
# 2296   31                55 1,071,432.00        False    False      False
#
#       m_woollam  n_de_clermont  s_james  female   male     no    yes  bind  \
# 833        True          False    False    True  False  False   True  True
# 1826      False           True    False   False   True   True  False  True
# 2247      False           True    False   False   True  False   True  True
# 1972      False          False    False   False   True   True  False  True
# 2296      False          False     True   False   True  False   True  True
#
#         ntu     forecast
# 833   False   786,861.09
# ...

# %% [markdown]
# # ***Model Output and Accuracy***

# %%
# assigning the column accuracy to x_test and then displaying the relevant output following the calculations
x_test['accuracy'] =  x_test.forecast/y_test.grossepi*100
x_test.head()
# Out:
#       age lloyds_claim_code      grosswp  a_colclough  d_hanly  m_esdaile  \
# 833    45                55   776,088.00        False    False      False
# 1826   55                20    58,458.00        False    False      False
# 2247   55                55   406,616.00        False    False      False
# 1972   37                20   618,822.00        False    False       True
# 2296   31                55 1,071,432.00        False    False      False
#
#       m_woollam  n_de_clermont  s_james  female   male     no    yes  bind  \
# 833        True          False    False    True  False  False   True  True
# 1826      False           True    False   False   True   True  False  True
# 2247      False           True    False   False   True  False   True  True
# 1972      False          False    False   False   True   True  False  True
# 2296      False          False     True   False   True  False   True  True
#
#         ntu     forecast  accuracy
# ...

# %%
# from matplotlib import pyplot as plt
# _df_17['grosswp'].plot(kind='hist', bins=20, title='grosswp')
# plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# # ***Trained Model Forecast for JNU International***

# %%
# setting the context and style of the regression plot
sb.set(context='paper', style='whitegrid', font_scale=1.2)

# setting the sub plot size
f, ax = plt.subplots(figsize = (6, 6))

# selecting the column for the regeression plot in x_test.
ax = sb.regplot(x=y_test.grossepi, y=x_test.forecast,
                  color = sb.color_palette("pastel")[0],)

f.suptitle(t = 'Forecast for AON Flux International', fontsize = 20, fontweight = 'bold')

yloc = np.arange(0,8000000,1000000)
ylab = [f"{int(num):,}" for num in np.array(yloc)/1000]
ax.set_yticks(yloc)
ax.set_yticklabels(ylab)
ax.set_ylabel(ylabel="Forecast ('000)", fontdict={'fontsize': 14, 'fontstyle': 'italic'})

xloc = np.arange(0,8000000,1000000)
xlab = [f"{int(num):,}" for num in np.array(xloc)/1000]
ax.set_xticks(xloc)
ax.set_xticklabels(xlab)
ax.set_xlabel(xlabel="GrossEPI ('000)", fontdict={'fontsize': 14, 'fontstyle': 'italic'})
# Out:
# Text(0.5, 0, "GrossEPI ('000)")

# %% [markdown]
# ## ***Output for Linear Regression Model***

# %% [markdown]
# # ***Multilayer Perceptron (MLP)***

# %%
# x_test.shape, x_train.shape, y_train.shape, y_test.shape

# %%
# # https://scikit-learn.org/stable/auto_examples/inspection/plot_partial_dependence.html#sphx-glr-auto-examples-inspection-plot-partial-dependence-py
# from sklearn.neural_network import MLPRegressor
# from sklearn.datasets import make_regression
# from sklearn.model_selection import train_test_split

# %%
# # assigning an instance of MLP to regr
# regr = MLPRegressor(random_state=1, max_iter=500).fit(x_train,y_train)

# %%
# # selecting every rows in my dataset.
# regr.predict(x_test)

# %%
# #  First MLP score output, return the coefficient of determination R-squared of the prediction
# regr.score(x_test, y_test)

# %%
15544-1016
# Out:
# 14528
